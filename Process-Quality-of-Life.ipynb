# %%
import pandas as pd
unique_city_names = pd.read_csv("uniqueCities.csv", names=["City"])
quality_of_life = pd.read_csv("movehubqualityoflife.csv")
quality_of_life
# Out:
#              City  Movehub Rating  Purchase Power  Health Care  Pollution  \
# 0         Caracas           65.18           11.25        44.44      83.45
# 1    Johannesburg           84.08           53.99        59.98      47.39
# 2       Fortaleza           80.17           52.28        45.46      66.32
# 3     Saint Louis           85.25           80.40        77.29      31.33
# 4     Mexico City           75.07           24.28        61.76      18.95
# ..            ...             ...             ...          ...        ...
# 211    Dusseldorf           83.45           72.52        75.98       8.61
# 212         Tokyo           80.00           47.57        71.53      30.54
# 213     Abu Dhabi           86.40           68.03        48.02      53.42
# 214      Marbella           81.96           60.14        83.64      32.27
# 215        Malaga           84.30           45.77        69.17      30.55
#
#      Quality of Life  Crime Rating
# 0               8.61         85.70
# ...

# %%
quality = quality_of_life.groupby(["City"]).mean()
quality_of_live = quality.filter(items=unique_city_names["City"], axis=0)
life_quality = quality_of_live["Quality of Life"]
life_quality.to_csv("./processed_quality_of_live.csv")
# Out:
#               Movehub Rating  Purchase Power  Health Care  Pollution  \
# City
# New York               90.53           55.56        51.39      12.01
# Los Angeles            86.86           62.75        68.61      75.20
# Chicago                83.01           66.77        62.92      22.98
# Houston                85.24           71.96        79.44      65.21
# Philadelphia           83.31           68.77        54.17      38.64
# ...                      ...             ...          ...        ...
# Manila                 68.31           14.80        80.56      65.22
# Varna                  71.11           20.34        50.23      80.84
# Darwin                 79.63           49.51        75.28       6.78
# Cologne                82.18           59.18        67.88      68.41
# Johannesburg           84.08           53.99        59.98      47.39
#
#               Quality of Life  Crime Rating
# City
# New York                61.94         47.33
# ...

# %%
low = quality_of_live['Quality of Life'].quantile(0.0)
mid = quality_of_live['Quality of Life'].quantile(0.33)
high = quality_of_live['Quality of Life'].quantile(0.67)

lowdf = quality_of_live.loc[(quality_of_live['Quality of Life'] > low) & (quality_of_live['Quality of Life'] <= mid)]
middf = quality_of_live.loc[(quality_of_live['Quality of Life'] > mid) & (quality_of_live['Quality of Life'] <= high)]
highdf = quality_of_live.loc[(quality_of_live['Quality of Life'] > high)]

rating = []
for i in range(0, len(lowdf.index)):
    rating.append('Life could be better')
lowdf["Quality of Life Rating"] = rating
rating.clear()



rating = []
for i in range(0, len(middf.index)):
    rating.append('Life is good')
middf["Quality of Life Rating"] = rating
rating.clear()

rating = []
for i in range(0, len(highdf.index)):
    rating.append('Doesn\'t get any better!')
highdf["Quality of Life Rating"] = rating
rating.clear()

all_ratings = pd.concat([lowdf, middf, highdf])
#all_ratings

lowdf
# Out:
# C:\Users\JAMil\anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# C:\Users\JAMil\anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\JAMil\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
rating_final = all_ratings.drop(['Quality of Life'], axis=1)
rating_final.to_csv(".\processed_quality_rating.csv")
